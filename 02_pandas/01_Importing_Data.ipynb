# %%
import pandas as pd
# Works perfectly (different data types)

# %%
filename = r"H:\MLOPS\MLOPS-Python\02_pandas\orders.csv"
pd.read_csv(filename)
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
f = r"H:\MLOPS\MLOPS-Python\02_pandas\big.txt"
df = pd.read_table(f, sep=" ", engine="python", on_bad_lines="skip")
print(df)
# Out:
#              The  Project Gutenberg        EBook       of      The.1  \
# 0             by      Sir    Arthur        Conan    Doyle       None
# 1           (#15       in       our       series       by        Sir
# 2      copyright     laws       for         your  country     before
# 3           this       or       any        other  Project  Gutenberg
# 4         header  without   written  permission.     None       None
# ...          ...      ...       ...          ...      ...        ...
# 44127        NaN      NaN       for            i       in  xrange(6,
# 44128        NaN      NaN       NaN          NaN        c          =
# 44129        NaN      NaN       NaN          NaN      NaN        NaN
# 44130        NaN      NaN     print            s     None       None
# 44131        NaN      NaN     print      [ord(c)      for          c
#
#         Adventures   of.1        Sherlock Holmes
# 0             None   None            None   None
# ...

# %%
file = r"H:\MLOPS\MLOPS-Python\02_pandas\Pandas-Example.xlsx"
df = pd.read_excel(file)
print(df)
# Out:
#       Patient   BP    SO2  DrFirst  DrLast  BP*SO2
# 0   Joe Smith  123  1.234    James  Rogers     NaN
# 1  Frank Blue   99  1.100  William    Kahn     NaN

# %%
import sqlite3
conn = sqlite3.connect(r"H:\MLOPS\MLOPS-Python\02_pandas\rideshare.db")

df = pd.read_sql("SELECT * FROM users", conn)
print(df)
# Out:
#       user_id              name                          email  \
# 0           1       David White          david.white@gmail.com
# 1           2      Justin Young        justin.young@icloud.com
# 2           3       Scott Kelly         scott.kelly@icloud.com
# 3           4  Dorothy Phillips     dorothy.phillips@yahoo.com
# 4           5   Barbara Johnson    barbara.johnson@hotmail.com
# ...       ...               ...                            ...
# 1995     1996     Anthony Lewis        anthony.lewis@yahoo.com
# 1996     1997        Amy Flores          amy.flores@icloud.com
# 1997     1998    Betty Campbell  betty.campbell@protonmail.com
# 1998     1999    William Wright      william.wright@icloud.com
# 1999     2000     Linda Stewart       linda.stewart@icloud.com
#
#                 phone         city date_joined  is_driver
# 0     +1-809-169-4853      Houston  2019-09-03          0
# 1     +1-808-140-2343      Houston  2022-09-08          1
# ...

# %%
df = pd.read_json(r"H:\MLOPS\MLOPS-Python\02_pandas\NCT04343053.json")
print(df)
# Out:
#                                                              clinical_study
# @rank                                                                   314
# acronym                                                            ATTAC-Co
# arm_group                 {'arm_group_label': 'SARS-Cov-2 infection', 'a...
# brief_summary             {'textblock': 'The present study is ideated to...
# brief_title               Pro-thrombotic Status in Patients With SARS-Co...
# completion_date           {'@type': 'Anticipated', '#text': 'June 30, 20...
# condition                   Severe Acute Respiratory Syndrome Coronavirus 2
# condition_browse          {'mesh_term': ['Coronavirus Infections', 'Seve...
# detailed_description      {'textblock': 'Preliminary evidences suggested...
# eligibility               {'criteria': {'textblock': 'Inclusion Criteria...
# enrollment                          {'@type': 'Anticipated', '#text': '60'}
# ...

# %%
# 
url = "https://www.w3schools.com/html/html_tables.asp"
df_list = pd.read_html(url)
print(len(df_list))   # number of tables
print(df_list[0].head())
# Out:
# 2
#                         Company          Contact  Country
# 0           Alfreds Futterkiste     Maria Anders  Germany
# 1    Centro comercial Moctezuma  Francisco Chang   Mexico
# 2                  Ernst Handel    Roland Mendel  Austria
# 3                Island Trading    Helen Bennett       UK
# 4  Laughing Bacchus Winecellars  Yoshi Tannamuri   Canada

# %%
# dict format
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Country': ['USA', 'Canada', 'UK']
}

df1 = pd.DataFrame(data)
print(df1)
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 1      Bob   30  Canada
# 2  Charlie   35      UK

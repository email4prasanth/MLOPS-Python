# %%
import pandas as pd

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35]
}
print(data)
print(type(data))

df = pd.DataFrame(data)
print("df\n",df)
print(f"Data types: \n{df.dtypes}")
df.to_csv("02_z-output.csv")
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
# <class 'dict'>
# df
#        Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# Data types:
# Name    object
# Age      int64
# dtype: object

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Country': ['USA', 'Canada', 'UK']
}
df = pd.DataFrame(data)

df.to_excel("02_z-output.xlsx")

# %%
df1 = df.to_json("02_z-output.json")

# %%
df2 = df.to_html("02_z-output.html")

# %%
import pandas as pd
print(pd.__version__)
f500 = pd.read_csv("f500.csv")
# Out:
# 2.1.3

# %%
print(f500)
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
# Basics
# data type of each column in a  DataFrame
col_types = f500.dtypes
print(col_types)
# Dimensions
dim = f500.shape
print("dimensions",dim)
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object
# dimensions (500, 17)

# %%
# selecting df values
print(f500[["rank","revenues","revenue_change","website"]])
# Out:
#      rank  revenues  revenue_change                       website
# 0       1    485873             0.8        http://www.walmart.com
# 1       2    315199            -4.4        http://www.sgcc.com.cn
# 2       3    267518            -9.1        http://www.sinopec.com
# 3       4    262573           -12.3        http://www.cnpc.com.cn
# 4       5    254694             7.7  http://www.toyota-global.com
# ..    ...       ...             ...                           ...
# 495   496     21903            11.5      http://www.tevapharm.com
# 496   497     21796           -13.3   http://www.newchinalife.com
# 497   498     21741           -11.3      http://www.morrisons.com
# 498   499     21655            -5.5       http://www.tuigroup.com
# 499   500     21609             3.6     http://www.autonation.com
#
# [500 rows x 4 columns]

# %%
# First 5 and last 5 rows
print(f500.head())
print(f500.tail())
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# ...

# %%
# select rows and columns
# Label-based indexing
# df.loc[row_label, column_label]
big_movers = f500.loc[f500["company"].isin(["Aviva","HP","JD.com", "BHP Billiton"]), ["rank","previous_rank"]]
print(big_movers)
# Out:
#      rank  previous_rank
# 89     90            279
# 193   194             48
# 260   261            366
# 349   350            168

# %%
check = f500.loc[f500["company"].isin(["Sinopec Group"]),["company","rank"]]
print("check",check)
print("###")

third_row_first_col = f500.iloc[ 2, 0]
print(third_row_first_col)
# Out:
# check          company  rank
# 2  Sinopec Group     3
# ###
# Sinopec Group

# %%
# Position-based indexing
second_row = f500.iloc[2]
print(second_row)
# Out:
# company                              Sinopec Group
# rank                                             3
# revenues                                    267518
# revenue_change                                -9.1
# profits                                     1257.9
# assets                                      310726
# profit_change                                -65.0
# ceo                                      Wang Yupu
# industry                        Petroleum Refining
# sector                                      Energy
# previous_rank                                    4
# country                                      China
# hq_location                         Beijing, China
# website                     http://www.sinopec.com
# years_on_global_500_list                        19
# employees                                   713288
# total_stockholder_equity                    106523
# Name: 2, dtype: object

# %%
rev_is_null = f500["revenue_change"].isnull()
print(rev_is_null)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: revenue_change, Length: 500, dtype: bool

# %%
# take true value and display
rev_change_null = f500[rev_is_null]
print(rev_change_null)
# Out:
#                         company  rank  revenues  revenue_change  profits  \
# 90                       Uniper    91     74407             NaN  -3557.5
# 180  Hewlett Packard Enterprise   181     50123             NaN   3161.0
#
#      assets  profit_change                  ceo  \
# 90    51541            NaN        Klaus Schafer
# 180   79679            NaN  Margaret C. Whitman
#
#                             industry      sector  previous_rank  country  \
# 90                            Energy      Energy              0  Germany
# 180  Information Technology Services  Technology              0      USA
#
#              hq_location                   website  years_on_global_500_list  \
# 90   Dusseldorf, Germany  http://www.uniper.energy                         1
# 180        Palo Alto, CA        http://www.hpe.com                         1
#
#      employees  total_stockholder_equity
# 90       12890                     12889
# 180     195000                     31448

# %%
print(f500[f500["previous_rank"].notnull()])
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
filter_big_rev_neg_profit = (f500["revenues"] > 100000) & (f500["profits"] <0)
print(filter_big_rev_neg_profit)
print(f500[filter_big_rev_neg_profit])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool
#                 company  rank  revenues  revenue_change  profits   assets  \
# 32  Japan Post Holdings    33    122990             3.6   -267.4  2631385
# 44              Chevron    45    107567           -18.0   -497.0   260078
#
#     profit_change               ceo                         industry  \
# 32         -107.5  Masatsugu Nagato  Insurance: Life, Health (stock)
# 44         -110.8    John S. Watson               Petroleum Refining
#
#         sector  previous_rank country    hq_location                  website  \
# 32  Financials             37   Japan   Tokyo, Japan  http://www.japanpost.jp
# 44      Energy             31     USA  San Ramon, CA   http://www.chevron.com
#
#     years_on_global_500_list  employees  total_stockholder_equity
# ...

# %%
revs = f500["revenues"] 
summary_stats = revs.describe()
print(summary_stats)
# Out:
# count       500.000000
# mean      55416.358000
# std       45725.478963
# min       21609.000000
# 25%       29003.000000
# 50%       40236.000000
# 75%       63926.750000
# max      485873.000000
# Name: revenues, dtype: float64

# %%
country_freqs = f500["country"].value_counts()
print(country_freqs)
print(sum(country_freqs))
# Out:
# country
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Italy             7
# Brazil            7
# India             7
# Australia         7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Luxembourg        1
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: count, dtype: int64
# 500

# %%
kr_bool = f500["country"] == "USA"
print(f500[kr_bool].head())
# Out:
#                company  rank  revenues  revenue_change  profits  assets  \
# 0              Walmart     1    485873             0.8  13643.0  198825
# 7   Berkshire Hathaway     8    223604             6.1  24074.0  620854
# 8                Apple     9    215639            -7.7  45687.0  321686
# 9          Exxon Mobil    10    205004           -16.7   7840.0  330314
# 10            McKesson    11    198533             3.1   5070.0   60969
#
#     profit_change                  ceo  \
# 0            -7.2  C. Douglas McMillon
# 7             NaN    Warren E. Buffett
# 8           -14.4      Timothy D. Cook
# 9           -51.5      Darren W. Woods
# 10          124.5   John H. Hammergren
#
#                                     industry       sector  previous_rank  \
# 0                      General Merchandisers    Retailing              1
# 7   Insurance: Property and Casualty (Stock)   Financials             11
# ...

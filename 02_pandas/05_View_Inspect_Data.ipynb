# %%
import numpy as np
import pandas as pd

# %%
data = np.random.randint(5,size=20)
df = pd.DataFrame(data)
print(df)
print(df.value_counts())
df.value_counts().sort_index()
# Out:
#     0
# 0   3
# 1   2
# 2   0
# 3   2
# 4   3
# 5   3
# 6   1
# 7   1
# 8   1
# 9   0
# 10  3
# 11  3
# 12  0
# 13  3
# 14  0
# 15  0
# 16  0
# 17  0
# 18  2
# 19  4
# 0    7
# 3    6
# 1    3
# 2    3
# 4    1
# Name: count, dtype: int64
# 0    7
# 1    3
# 2    3
# 3    6
# 4    1
# Name: count, dtype: int64

# %%
# Histogram
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Vertical bar plot
df.plot.bar()
# Out:
# <Axes: >

# %%
# Horizantal bar plot
df.plot.barh()
# Out:
# <Axes: >

# %%
f500 = pd.read_csv("f500.csv")
f500.plot.line(x='rank',y='revenue_change')
# Out:
# <Axes: xlabel='rank'>

# %%
f500.plot.scatter(x='rank',y='revenue_change')
# Out:
# <Axes: xlabel='rank', ylabel='revenue_change'>

# %%
f500.head(2)
# Out:
#       company  rank  revenues  revenue_change  profits  assets  profit_change  \
# 0     Walmart     1    485873             0.8  13643.0  198825           -7.2
# 1  State Grid     2    315199            -4.4   9571.3  489838           -6.2
#
#                    ceo               industry     sector  previous_rank  \
# 0  C. Douglas McMillon  General Merchandisers  Retailing              1
# 1              Kou Wei              Utilities     Energy              2
#
#   country      hq_location                 website  years_on_global_500_list  \
# 0     USA  Bentonville, AR  http://www.walmart.com                        23
# 1   China   Beijing, China  http://www.sgcc.com.cn                        17
#
#    employees  total_stockholder_equity
# 0    2300000                     77798
# 1     926067                    209456

# %%
df = pd.read_csv(r"H:\MLOPS\MLOPS-Python\02_pandas\f500.csv")
df.tail(4)
# Out:
#                        company  rank  revenues  revenue_change  profits  \
# 496   New China Life Insurance   497     21796           -13.3    743.9
# 497  Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                        TUI   499     21655            -5.5   1151.7
# 499                 AutoNation   500     21609             3.6    430.5
#
#      assets  profit_change                 ceo  \
# 496  100609          -45.6            Wan Feng
# 497   11630           20.4      David T. Potts
# 498   16247          195.5   Friedrich Joussen
# 499   10060           -2.7  Michael J. Jackson
#
#                             industry              sector  previous_rank  \
# 496  Insurance: Life, Health (stock)          Financials            427
# 497             Food and Drug Stores  Food & Drug Stores            437
# 498                  Travel Services   Business Services            467
# 499              Specialty Retailers           Retailing              0
#
# ...

# %%
df
print(df.shape)
df.info
# Out:
# (500, 17)
# <bound method DataFrame.info of                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
df["country"].value_counts().sort_index()
# Out:
# country
# Australia         7
# Belgium           1
# Brazil            7
# Britain          24
# Canada           11
# China           109
# Denmark           1
# Finland           1
# France           29
# Germany          29
# India             7
# Indonesia         1
# Ireland           4
# Israel            1
# Italy             7
# Japan            51
# Luxembourg        1
# Malaysia          1
# Mexico            2
# Netherlands      14
# Norway            1
# Russia            4
# Saudi Arabia      1
# Singapore         3
# South Korea      15
# Spain             9
# Sweden            3
# Switzerland      14
# Taiwan            6
# Thailand          1
# Turkey            1
# U.A.E             1
# USA             132
# Venezuela         1
# Name: count, dtype: int64

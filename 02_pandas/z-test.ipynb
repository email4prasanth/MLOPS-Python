# %%
import pandas as pd
import numpy as np

# %%
# Q1. Load a CSV file into a DataFrame. Write code to: 
# (a) View first 10 rows 
# (b) Get shape 
# (c) View data types
df = pd.read_csv(r"H:\MLOPS\MLOPS-Python\02_pandas\f500.csv")
print(f"View first 10 rows:\n{df.head(10)}")
print(f"shape of the dataframe:\n{np.shape(df)}")
print(df.dtypes)
# Out:
# company                      object
# rank                          int64
# revenues                      int64
# revenue_change              float64
# profits                     float64
# assets                        int64
# profit_change               float64
# ceo                          object
# industry                     object
# sector                       object
# previous_rank                 int64
# country                      object
# hq_location                  object
# website                      object
# years_on_global_500_list      int64
# employees                     int64
# total_stockholder_equity      int64
# dtype: object

# %%
# Q2. Write code to select: (a) Column 'revenues' (b) Columns 'country' and 'profit'
print(f"Revenue:\n {df[["revenues"]]}")
print(f"country and profit:\n {df[["country","profits"]]}")
# Out:
# Revenue:
#       revenues
# 0      485873
# 1      315199
# 2      267518
# 3      262573
# 4      254694
# ..        ...
# 495     21903
# 496     21796
# 497     21741
# 498     21655
# 499     21609
#
# [500 rows x 1 columns]
# country and profit:
#       country  profits
# 0        USA  13643.0
# 1      China   9571.3
# 2      China   1257.9
# 3      China   1867.5
# 4      Japan  16899.3
# ..       ...      ...
# 495   Israel    329.0
# 496    China    743.9
# 497  Britain    406.4
# 498  Germany   1151.7
# 499      USA    430.5
#
# [500 rows x 2 columns]

# %%
# Q3. Filter rows where revenue > 100000 and profit < 0.
df[(df['revenues'] >10000) & (df["profits"] <0)]
# Out:
#                                 company  rank  revenues  revenue_change  \
# 32                  Japan Post Holdings    33    122990             3.6
# 44                              Chevron    45    107567           -18.0
# 74                            Petrobras    75     81405           -16.3
# 90                               Uniper    91     74407             NaN
# 91                                Tesco    92     74393           -15.1
# 92                                Engie    93     73692            -4.9
# 98                  U.S. Postal Service    99     71498             3.7
# 119                     China Minmetals   120     65547           105.6
# 123                   Dell Technologies   124     64806            18.1
# 131                                 ENI   132     62694           -32.6
# 140                     Albertsons Cos.   141     59678             1.6
# 148                      Vodafone Group   149     58611            -5.0
# ...

# %%
# Q4. In column 'employees': (a) Count null values (b) Replace nulls with mean
df1 = df['employees'].notnull().value_counts()
df['employees'] = df['employees'].fillna(df['employees'].mean())
df
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

# %%
# Q5. Group by 'country' and compute average revenue.
df = pd.read_csv(r'H:\MLOPS\MLOPS-Python\02_pandas\f500.csv')
df.groupby(['country'])['revenues'].mean()
# Out:
# country
# Australia       33688.714286
# Belgium         45905.000000
# Brazil          52024.571429
# Britain         51588.708333
# Canada          31848.000000
# China           55397.880734
# Denmark         35464.000000
# Finland         26113.000000
# France          55231.793103
# Germany         63915.000000
# India           39993.000000
# Indonesia       36487.000000
# Ireland         32819.500000
# Israel          21903.000000
# Italy           51899.571429
# Japan           53164.039216
# Luxembourg      56791.000000
# Malaysia        49479.000000
# Mexico          54987.500000
# Netherlands     61708.928571
# Norway          45873.000000
# Russia          65247.750000
# Saudi Arabia    35421.000000
# Singapore       54454.333333
# South Korea     49725.600000
# Spain           40600.666667
# Sweden          27963.666667
# Switzerland     51353.571429
# Taiwan          46364.666667
# Thailand        48719.000000
# Turkey          23456.000000
# ...

# %%
# Q6. Sort by 'revenues' descending and 'profits' ascending.
df.sort_values(['revenues','profits'], ascending=[False,True])
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
# ...

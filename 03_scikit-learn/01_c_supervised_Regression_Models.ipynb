# %%
from sklearn import datasets
# Load Diabetes dataset (REGRESSION)
diabetes = datasets.load_diabetes()
print(diabetes.keys())
print(diabetes.feature_names)
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
# prepare train and test data
from sklearn.model_selection import train_test_split
X = diabetes.data[:,:2]
y = diabetes.target
print(X,y)
print(f"Dataset shape: {X.shape}")
print(f"Target range: {y.min():.1f} to {y.max():.1f} (continuous values)")
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.15, random_state=22)
# Out:
# [[ 0.03807591  0.05068012]
#  [-0.00188202 -0.04464164]
#  [ 0.08529891  0.05068012]
#  [-0.08906294 -0.04464164]
#  [ 0.00538306 -0.04464164]
#  [-0.09269548 -0.04464164]
#  [-0.04547248  0.05068012]
#  [ 0.06350368  0.05068012]
#  [ 0.04170844  0.05068012]
#  [-0.07090025 -0.04464164]
#  [-0.09632802 -0.04464164]
#  [ 0.02717829  0.05068012]
#  [ 0.01628068 -0.04464164]
#  [ 0.00538306  0.05068012]
#  [ 0.04534098 -0.04464164]
#  [-0.05273755  0.05068012]
#  [-0.00551455 -0.04464164]
#  [ 0.07076875  0.05068012]
#  [-0.0382074  -0.04464164]
#  [-0.02730979 -0.04464164]
#  [-0.04910502 -0.04464164]
#  [-0.0854304   0.05068012]
#  [-0.0854304  -0.04464164]
#  [ 0.04534098  0.05068012]
#  [-0.06363517 -0.04464164]
#  [-0.06726771  0.05068012]
#  [-0.10722563 -0.04464164]
#  [-0.02367725 -0.04464164]
#  [ 0.05260606 -0.04464164]
#  [ 0.06713621  0.05068012]
#  [-0.06000263 -0.04464164]
#  [-0.02367725 -0.04464164]
#  [ 0.03444337  0.05068012]
#  [ 0.03081083 -0.04464164]
# ...

# %%
# Store results in a dictionary
results = {}

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
y_pred = lr_model.predict(X_test)
acc_score = mean_squared_error(y_test, y_pred)
print(acc_score)
results['Linear Regression'] = {
    'MSE': mean_squared_error(y_test, y_pred),
    'RMSE': np.sqrt(mean_squared_error(y_test, y_pred)),
    'R2': r2_score(y_test, y_pred)
}
print(results)
# Out:
# 5702.101051525619
# {'Linear Regression': {'MSE': 5702.101051525619, 'RMSE': 75.51225762434612, 'R2': 0.042390136515045196}}

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
knr_model = KNeighborsRegressor()
knr_model.fit(X_train, y_train)
y_pred = knr_model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
results['KNN Regressor'] = {
    'MSE': mean_squared_error(y_test, y_pred),
    'RMSE': np.sqrt(mean_squared_error(y_test, y_pred)),
    'R2': r2_score(y_test, y_pred)
}
print(results)
# Out:
# 6126.136119402985
# {'Linear Regression': {'MSE': 5702.101051525619, 'RMSE': 75.51225762434612, 'R2': 0.042390136515045196}, 'KNN Regressor': {'MSE': 6126.136119402985, 'RMSE': 78.26963727655179, 'R2': -0.028822239378264225}}

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
svr_model = SVR()
svr_model.fit(X_train, y_train)
y_pred = svr_model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
results['SVR'] = {
    'MSE': mean_squared_error(y_test, y_pred),
    'RMSE': np.sqrt(mean_squared_error(y_test, y_pred)),
    'R2': r2_score(y_test, y_pred)
}
# Out:
# 0.4115320079476209

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
dvr_model = DecisionTreeRegressor()
dvr_model.fit(X_train, y_train)
y_pred = dvr_model.predict(X_test)
print(mean_squared_error(y_test, y_pred))
results['Decision Tree'] = {
    'MSE': mean_squared_error(y_test, y_pred),
    'RMSE': np.sqrt(mean_squared_error(y_test, y_pred)),
    'R2': r2_score(y_test, y_pred)
}
# Out:
# 0.6296296296296297

# %%
# Create comparison DataFrame
import pandas as pd
comparison_df = pd.DataFrame(results).T
print("\n" + "="*50)
print("MODEL COMPARISON RESULTS")
print("="*50)
print(comparison_df.round(4))

# Find best model for each metric
print("\n" + "="*50)
print("BEST MODELS")
print("="*50)
print(f"Lowest MSE:  {comparison_df['MSE'].idxmin()} ({comparison_df['MSE'].min():.4f})")
print(f"Lowest RMSE: {comparison_df['RMSE'].idxmin()} ({comparison_df['RMSE'].min():.4f})")
print(f"Highest R2:  {comparison_df['R2'].idxmax()} ({comparison_df['R2'].max():.4f})")
# Out:
# ...
# MODEL COMPARISON RESULTS
# ...
#                       MSE    RMSE      R2
# Linear Regression  0.4434  0.6659  0.1999
# KNeighbours        0.3067  0.5538  0.4466
# SVR                0.4115  0.6415  0.2574
# KNN Regressor      0.3067  0.5538  0.4466
# Decision Tree      0.6296  0.7935 -0.1361
#
# ...
# BEST MODELS
# ...
# Lowest MSE:  KNeighbours (0.3067)
# Lowest RMSE: KNeighbours (0.5538)
# Highest R2:  KNeighbours (0.4466)
